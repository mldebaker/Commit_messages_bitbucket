# %% [markdown]
# # API Test Calance US Loop Version

# %%
# Dependencies and Setup
import pandas as pd
import requests
import json

# %%
# Make Request tor Commit Comment b2b08f6
response = requests.get('https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commits')
json1 = response.json()
# Display to find location
print(json.dumps(json1, indent=5, sort_keys=True))
# Out:
# {
#      "pagelen": 30,
#      "values": [
#           {
#                "author": {
#                     "raw": "Daniel Williams <dwilliams@calance.com>",
#                     "type": "author",
#                     "user": {
#                          "account_id": "557058:618c6868-28c1-4328-ad4e-6534acbb5e4e",
#                          "display_name": "Daniel Williams",
#                          "links": {
#                               "avatar": {
#                                    "href": "https://secure.gravatar.com/avatar/f9e4698b399154b37b07af39d86878bb?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FDW-6.png"
#                               },
#                               "html": {
#                                    "href": "https://bitbucket.org/%7B11c4ad47-6dbf-4da7-95eb-39d6e0a7dc30%7D/"
#                               },
#                               "self": {
#                                    "href": "https://api.bitbucket.org/2.0/users/%7B11c4ad47-6dbf-4da7-95eb-39d6e0a7dc30%7D"
#                               }
#                          },
#                          "nickname": "Daniel Williams",
#                          "type": "user",
#                          "uuid": "{11c4ad47-6dbf-4da7-95eb-39d6e0a7dc30}"
#                     }
#                },
#                "date": "2019-12-17T18:04:05+00:00",
#                "hash": "9a472d27e381b209e76fc798c3ca1c6dfb55e2bc",
#                "links": {
#                     "approve": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/9a472d27e381b209e76fc798c3ca1c6dfb55e2bc/approve"
#                     },
#                     "comments": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/9a472d27e381b209e76fc798c3ca1c6dfb55e2bc/comments"
#                     },
#                     "diff": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/diff/9a472d27e381b209e76fc798c3ca1c6dfb55e2bc"
#                     },
#                     "html": {
#                          "href": "https://bitbucket.org/calanceus/api-test/commits/9a472d27e381b209e76fc798c3ca1c6dfb55e2bc"
#                     },
#                     "patch": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/patch/9a472d27e381b209e76fc798c3ca1c6dfb55e2bc"
#                     },
#                     "self": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/9a472d27e381b209e76fc798c3ca1c6dfb55e2bc"
#                     },
#                     "statuses": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/9a472d27e381b209e76fc798c3ca1c6dfb55e2bc/statuses"
#                     }
#                },
#                "message": "Adding a 2019 comment",
#                "parents": [
#                     {
#                          "hash": "b2b08f699f0590716808b70a8d8d3d4063bf436e",
#                          "links": {
#                               "html": {
#                                    "href": "https://bitbucket.org/calanceus/api-test/commits/b2b08f699f0590716808b70a8d8d3d4063bf436e"
#                               },
#                               "self": {
#                                    "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/b2b08f699f0590716808b70a8d8d3d4063bf436e"
#                               }
#                          },
#                          "type": "commit"
#                     }
#                ],
#                "rendered": {
#                     "message": {
#                          "html": "<p>Adding a 2019 comment</p>",
#                          "markup": "markdown",
#                          "raw": "Adding a 2019 comment",
#                          "type": "rendered"
#                     }
#                },
#                "repository": {
#                     "full_name": "calanceus/api-test",
#                     "links": {
#                          "avatar": {
#                               "href": "https://bytebucket.org/ravatar/%7B38b213d6-3967-4cf8-a92d-8b145c54588a%7D?ts=default"
#                          },
#                          "html": {
#                               "href": "https://bitbucket.org/calanceus/api-test"
#                          },
#                          "self": {
#                               "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test"
#                          }
#                     },
#                     "name": "API Test",
#                     "type": "repository",
#                     "uuid": "{38b213d6-3967-4cf8-a92d-8b145c54588a}"
#                },
#                "summary": {
#                     "html": "<p>Adding a 2019 comment</p>",
#                     "markup": "markdown",
#                     "raw": "Adding a 2019 comment",
#                     "type": "rendered"
#                },
#                "type": "commit"
#           },
#           {
#                "author": {
#                     "raw": "Daniel Williams <dwilliams@calance.com>",
#                     "type": "author",
#                     "user": {
#                          "account_id": "557058:618c6868-28c1-4328-ad4e-6534acbb5e4e",
#                          "display_name": "Daniel Williams",
#                          "links": {
#                               "avatar": {
#                                    "href": "https://secure.gravatar.com/avatar/f9e4698b399154b37b07af39d86878bb?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FDW-6.png"
#                               },
#                               "html": {
#                                    "href": "https://bitbucket.org/%7B11c4ad47-6dbf-4da7-95eb-39d6e0a7dc30%7D/"
#                               },
#                               "self": {
#                                    "href": "https://api.bitbucket.org/2.0/users/%7B11c4ad47-6dbf-4da7-95eb-39d6e0a7dc30%7D"
#                               }
#                          },
#                          "nickname": "Daniel Williams",
#                          "type": "user",
#                          "uuid": "{11c4ad47-6dbf-4da7-95eb-39d6e0a7dc30}"
#                     }
#                },
#                "date": "2019-04-21T22:47:55+00:00",
#                "hash": "b2b08f699f0590716808b70a8d8d3d4063bf436e",
#                "links": {
#                     "approve": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/b2b08f699f0590716808b70a8d8d3d4063bf436e/approve"
#                     },
#                     "comments": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/b2b08f699f0590716808b70a8d8d3d4063bf436e/comments"
#                     },
#                     "diff": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/diff/b2b08f699f0590716808b70a8d8d3d4063bf436e"
#                     },
#                     "html": {
#                          "href": "https://bitbucket.org/calanceus/api-test/commits/b2b08f699f0590716808b70a8d8d3d4063bf436e"
#                     },
#                     "patch": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/patch/b2b08f699f0590716808b70a8d8d3d4063bf436e"
#                     },
#                     "self": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/b2b08f699f0590716808b70a8d8d3d4063bf436e"
#                     },
#                     "statuses": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/b2b08f699f0590716808b70a8d8d3d4063bf436e/statuses"
#                     }
#                },
#                "message": "simple edit\n",
#                "parents": [
#                     {
#                          "hash": "9de016dd4e237590af8b97ec34f7076b562e91df",
#                          "links": {
#                               "html": {
#                                    "href": "https://bitbucket.org/calanceus/api-test/commits/9de016dd4e237590af8b97ec34f7076b562e91df"
#                               },
#                               "self": {
#                                    "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/9de016dd4e237590af8b97ec34f7076b562e91df"
#                               }
#                          },
#                          "type": "commit"
#                     }
#                ],
#                "rendered": {
#                     "message": {
#                          "html": "<p>simple edit</p>",
#                          "markup": "markdown",
#                          "raw": "simple edit\n",
#                          "type": "rendered"
#                     }
#                },
#                "repository": {
#                     "full_name": "calanceus/api-test",
#                     "links": {
#                          "avatar": {
#                               "href": "https://bytebucket.org/ravatar/%7B38b213d6-3967-4cf8-a92d-8b145c54588a%7D?ts=default"
#                          },
#                          "html": {
#                               "href": "https://bitbucket.org/calanceus/api-test"
#                          },
#                          "self": {
#                               "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test"
#                          }
#                     },
#                     "name": "API Test",
#                     "type": "repository",
#                     "uuid": "{38b213d6-3967-4cf8-a92d-8b145c54588a}"
#                },
#                "summary": {
#                     "html": "<p>simple edit</p>",
#                     "markup": "markdown",
#                     "raw": "simple edit\n",
#                     "type": "rendered"
#                },
#                "type": "commit"
#           },
#           {
#                "author": {
#                     "raw": "mxhammons <mxhammons@gmail.com>",
#                     "type": "author",
#                     "user": {
#                          "account_id": "557058:33ac3923-87e3-4ce4-bd4e-0e8d088e5a00",
#                          "display_name": "Michael Hammons",
#                          "links": {
#                               "avatar": {
#                                    "href": "https://secure.gravatar.com/avatar/005c0ebcf682ec2a9de9a91d6804b96e?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FMH-0.png"
#                               },
#                               "html": {
#                                    "href": "https://bitbucket.org/%7B0144db50-6516-4ec6-81fe-8f73536e73af%7D/"
#                               },
#                               "self": {
#                                    "href": "https://api.bitbucket.org/2.0/users/%7B0144db50-6516-4ec6-81fe-8f73536e73af%7D"
#                               }
#                          },
#                          "nickname": "mhammons",
#                          "type": "user",
#                          "uuid": "{0144db50-6516-4ec6-81fe-8f73536e73af}"
#                     }
#                },
#                "date": "2016-12-06T17:09:30+00:00",
#                "hash": "9de016dd4e237590af8b97ec34f7076b562e91df",
#                "links": {
#                     "approve": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/9de016dd4e237590af8b97ec34f7076b562e91df/approve"
#                     },
#                     "comments": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/9de016dd4e237590af8b97ec34f7076b562e91df/comments"
#                     },
#                     "diff": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/diff/9de016dd4e237590af8b97ec34f7076b562e91df"
#                     },
#                     "html": {
#                          "href": "https://bitbucket.org/calanceus/api-test/commits/9de016dd4e237590af8b97ec34f7076b562e91df"
#                     },
#                     "patch": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/patch/9de016dd4e237590af8b97ec34f7076b562e91df"
#                     },
#                     "self": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/9de016dd4e237590af8b97ec34f7076b562e91df"
#                     },
#                     "statuses": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/9de016dd4e237590af8b97ec34f7076b562e91df/statuses"
#                     }
#                },
#                "message": "line break\n",
#                "parents": [
#                     {
#                          "hash": "ce03dc005d1f34b4026d4968d24b3f7192652ad1",
#                          "links": {
#                               "html": {
#                                    "href": "https://bitbucket.org/calanceus/api-test/commits/ce03dc005d1f34b4026d4968d24b3f7192652ad1"
#                               },
#                               "self": {
#                                    "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/ce03dc005d1f34b4026d4968d24b3f7192652ad1"
#                               }
#                          },
#                          "type": "commit"
#                     }
#                ],
#                "rendered": {
#                     "message": {
#                          "html": "<p>line break</p>",
#                          "markup": "markdown",
#                          "raw": "line break\n",
#                          "type": "rendered"
#                     }
#                },
#                "repository": {
#                     "full_name": "calanceus/api-test",
#                     "links": {
#                          "avatar": {
#                               "href": "https://bytebucket.org/ravatar/%7B38b213d6-3967-4cf8-a92d-8b145c54588a%7D?ts=default"
#                          },
#                          "html": {
#                               "href": "https://bitbucket.org/calanceus/api-test"
#                          },
#                          "self": {
#                               "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test"
#                          }
#                     },
#                     "name": "API Test",
#                     "type": "repository",
#                     "uuid": "{38b213d6-3967-4cf8-a92d-8b145c54588a}"
#                },
#                "summary": {
#                     "html": "<p>line break</p>",
#                     "markup": "markdown",
#                     "raw": "line break\n",
#                     "type": "rendered"
#                },
#                "type": "commit"
#           },
#           {
#                "author": {
#                     "raw": "mhammons <mxhammons@gmail.com>",
#                     "type": "author",
#                     "user": {
#                          "account_id": "557058:33ac3923-87e3-4ce4-bd4e-0e8d088e5a00",
#                          "display_name": "Michael Hammons",
#                          "links": {
#                               "avatar": {
#                                    "href": "https://secure.gravatar.com/avatar/005c0ebcf682ec2a9de9a91d6804b96e?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FMH-0.png"
#                               },
#                               "html": {
#                                    "href": "https://bitbucket.org/%7B0144db50-6516-4ec6-81fe-8f73536e73af%7D/"
#                               },
#                               "self": {
#                                    "href": "https://api.bitbucket.org/2.0/users/%7B0144db50-6516-4ec6-81fe-8f73536e73af%7D"
#                               }
#                          },
#                          "nickname": "mhammons",
#                          "type": "user",
#                          "uuid": "{0144db50-6516-4ec6-81fe-8f73536e73af}"
#                     }
#                },
#                "date": "2016-04-16T04:28:46+00:00",
#                "hash": "ce03dc005d1f34b4026d4968d24b3f7192652ad1",
#                "links": {
#                     "approve": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/ce03dc005d1f34b4026d4968d24b3f7192652ad1/approve"
#                     },
#                     "comments": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/ce03dc005d1f34b4026d4968d24b3f7192652ad1/comments"
#                     },
#                     "diff": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/diff/ce03dc005d1f34b4026d4968d24b3f7192652ad1"
#                     },
#                     "html": {
#                          "href": "https://bitbucket.org/calanceus/api-test/commits/ce03dc005d1f34b4026d4968d24b3f7192652ad1"
#                     },
#                     "patch": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/patch/ce03dc005d1f34b4026d4968d24b3f7192652ad1"
#                     },
#                     "self": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/ce03dc005d1f34b4026d4968d24b3f7192652ad1"
#                     },
#                     "statuses": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/ce03dc005d1f34b4026d4968d24b3f7192652ad1/statuses"
#                     }
#                },
#                "message": "\"hello world\", she said.\n",
#                "parents": [
#                     {
#                          "hash": "5c69e6a4a097f80d600ac5cd4e23753defc49d73",
#                          "links": {
#                               "html": {
#                                    "href": "https://bitbucket.org/calanceus/api-test/commits/5c69e6a4a097f80d600ac5cd4e23753defc49d73"
#                               },
#                               "self": {
#                                    "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/5c69e6a4a097f80d600ac5cd4e23753defc49d73"
#                               }
#                          },
#                          "type": "commit"
#                     }
#                ],
#                "rendered": {
#                     "message": {
#                          "html": "<p>\"hello world\", she said.</p>",
#                          "markup": "markdown",
#                          "raw": "\"hello world\", she said.\n",
#                          "type": "rendered"
#                     }
#                },
#                "repository": {
#                     "full_name": "calanceus/api-test",
#                     "links": {
#                          "avatar": {
#                               "href": "https://bytebucket.org/ravatar/%7B38b213d6-3967-4cf8-a92d-8b145c54588a%7D?ts=default"
#                          },
#                          "html": {
#                               "href": "https://bitbucket.org/calanceus/api-test"
#                          },
#                          "self": {
#                               "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test"
#                          }
#                     },
#                     "name": "API Test",
#                     "type": "repository",
#                     "uuid": "{38b213d6-3967-4cf8-a92d-8b145c54588a}"
#                },
#                "summary": {
#                     "html": "<p>\"hello world\", she said.</p>",
#                     "markup": "markdown",
#                     "raw": "\"hello world\", she said.\n",
#                     "type": "rendered"
#                },
#                "type": "commit"
#           },
#           {
#                "author": {
#                     "raw": "mhammons <mxhammons@gmail.com>",
#                     "type": "author",
#                     "user": {
#                          "account_id": "557058:33ac3923-87e3-4ce4-bd4e-0e8d088e5a00",
#                          "display_name": "Michael Hammons",
#                          "links": {
#                               "avatar": {
#                                    "href": "https://secure.gravatar.com/avatar/005c0ebcf682ec2a9de9a91d6804b96e?d=https%3A%2F%2Favatar-management--avatars.us-west-2.prod.public.atl-paas.net%2Finitials%2FMH-0.png"
#                               },
#                               "html": {
#                                    "href": "https://bitbucket.org/%7B0144db50-6516-4ec6-81fe-8f73536e73af%7D/"
#                               },
#                               "self": {
#                                    "href": "https://api.bitbucket.org/2.0/users/%7B0144db50-6516-4ec6-81fe-8f73536e73af%7D"
#                               }
#                          },
#                          "nickname": "mhammons",
#                          "type": "user",
#                          "uuid": "{0144db50-6516-4ec6-81fe-8f73536e73af}"
#                     }
#                },
#                "date": "2016-04-16T04:17:30+00:00",
#                "hash": "5c69e6a4a097f80d600ac5cd4e23753defc49d73",
#                "links": {
#                     "approve": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/5c69e6a4a097f80d600ac5cd4e23753defc49d73/approve"
#                     },
#                     "comments": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/5c69e6a4a097f80d600ac5cd4e23753defc49d73/comments"
#                     },
#                     "diff": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/diff/5c69e6a4a097f80d600ac5cd4e23753defc49d73"
#                     },
#                     "html": {
#                          "href": "https://bitbucket.org/calanceus/api-test/commits/5c69e6a4a097f80d600ac5cd4e23753defc49d73"
#                     },
#                     "patch": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/patch/5c69e6a4a097f80d600ac5cd4e23753defc49d73"
#                     },
#                     "self": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/5c69e6a4a097f80d600ac5cd4e23753defc49d73"
#                     },
#                     "statuses": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/5c69e6a4a097f80d600ac5cd4e23753defc49d73/statuses"
#                     }
#                },
#                "message": "Another comment.\n",
#                "parents": [
#                     {
#                          "hash": "3aab06e64e43bad171ba1399dd6b2b6e45e647b1",
#                          "links": {
#                               "html": {
#                                    "href": "https://bitbucket.org/calanceus/api-test/commits/3aab06e64e43bad171ba1399dd6b2b6e45e647b1"
#                               },
#                               "self": {
#                                    "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/3aab06e64e43bad171ba1399dd6b2b6e45e647b1"
#                               }
#                          },
#                          "type": "commit"
#                     }
#                ],
#                "rendered": {
#                     "message": {
#                          "html": "<p>Another comment.</p>",
#                          "markup": "markdown",
#                          "raw": "Another comment.\n",
#                          "type": "rendered"
#                     }
#                },
#                "repository": {
#                     "full_name": "calanceus/api-test",
#                     "links": {
#                          "avatar": {
#                               "href": "https://bytebucket.org/ravatar/%7B38b213d6-3967-4cf8-a92d-8b145c54588a%7D?ts=default"
#                          },
#                          "html": {
#                               "href": "https://bitbucket.org/calanceus/api-test"
#                          },
#                          "self": {
#                               "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test"
#                          }
#                     },
#                     "name": "API Test",
#                     "type": "repository",
#                     "uuid": "{38b213d6-3967-4cf8-a92d-8b145c54588a}"
#                },
#                "summary": {
#                     "html": "<p>Another comment.</p>",
#                     "markup": "markdown",
#                     "raw": "Another comment.\n",
#                     "type": "rendered"
#                },
#                "type": "commit"
#           },
#           {
#                "author": {
#                     "raw": "mhammons <mxhammons@calance.com>",
#                     "type": "author"
#                },
#                "date": "2016-04-15T18:56:38+00:00",
#                "hash": "3aab06e64e43bad171ba1399dd6b2b6e45e647b1",
#                "links": {
#                     "approve": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/3aab06e64e43bad171ba1399dd6b2b6e45e647b1/approve"
#                     },
#                     "comments": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/3aab06e64e43bad171ba1399dd6b2b6e45e647b1/comments"
#                     },
#                     "diff": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/diff/3aab06e64e43bad171ba1399dd6b2b6e45e647b1"
#                     },
#                     "html": {
#                          "href": "https://bitbucket.org/calanceus/api-test/commits/3aab06e64e43bad171ba1399dd6b2b6e45e647b1"
#                     },
#                     "patch": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/patch/3aab06e64e43bad171ba1399dd6b2b6e45e647b1"
#                     },
#                     "self": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/3aab06e64e43bad171ba1399dd6b2b6e45e647b1"
#                     },
#                     "statuses": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/3aab06e64e43bad171ba1399dd6b2b6e45e647b1/statuses"
#                     }
#                },
#                "message": "I am the walrus.\n",
#                "parents": [
#                     {
#                          "hash": "bf43da587df9817f17ef888eae9651eaa3373cf1",
#                          "links": {
#                               "html": {
#                                    "href": "https://bitbucket.org/calanceus/api-test/commits/bf43da587df9817f17ef888eae9651eaa3373cf1"
#                               },
#                               "self": {
#                                    "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/bf43da587df9817f17ef888eae9651eaa3373cf1"
#                               }
#                          },
#                          "type": "commit"
#                     }
#                ],
#                "rendered": {
#                     "message": {
#                          "html": "<p>I am the walrus.</p>",
#                          "markup": "markdown",
#                          "raw": "I am the walrus.\n",
#                          "type": "rendered"
#                     }
#                },
#                "repository": {
#                     "full_name": "calanceus/api-test",
#                     "links": {
#                          "avatar": {
#                               "href": "https://bytebucket.org/ravatar/%7B38b213d6-3967-4cf8-a92d-8b145c54588a%7D?ts=default"
#                          },
#                          "html": {
#                               "href": "https://bitbucket.org/calanceus/api-test"
#                          },
#                          "self": {
#                               "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test"
#                          }
#                     },
#                     "name": "API Test",
#                     "type": "repository",
#                     "uuid": "{38b213d6-3967-4cf8-a92d-8b145c54588a}"
#                },
#                "summary": {
#                     "html": "<p>I am the walrus.</p>",
#                     "markup": "markdown",
#                     "raw": "I am the walrus.\n",
#                     "type": "rendered"
#                },
#                "type": "commit"
#           },
#           {
#                "author": {
#                     "raw": "mhammons <mxhammons@calance.com>",
#                     "type": "author"
#                },
#                "date": "2016-04-15T18:55:42+00:00",
#                "hash": "bf43da587df9817f17ef888eae9651eaa3373cf1",
#                "links": {
#                     "approve": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/bf43da587df9817f17ef888eae9651eaa3373cf1/approve"
#                     },
#                     "comments": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/bf43da587df9817f17ef888eae9651eaa3373cf1/comments"
#                     },
#                     "diff": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/diff/bf43da587df9817f17ef888eae9651eaa3373cf1"
#                     },
#                     "html": {
#                          "href": "https://bitbucket.org/calanceus/api-test/commits/bf43da587df9817f17ef888eae9651eaa3373cf1"
#                     },
#                     "patch": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/patch/bf43da587df9817f17ef888eae9651eaa3373cf1"
#                     },
#                     "self": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/bf43da587df9817f17ef888eae9651eaa3373cf1"
#                     },
#                     "statuses": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/bf43da587df9817f17ef888eae9651eaa3373cf1/statuses"
#                     }
#                },
#                "message": "Commit #2!\n",
#                "parents": [
#                     {
#                          "hash": "947362ec4e9ab99f63ca09f799f91f237557e35f",
#                          "links": {
#                               "html": {
#                                    "href": "https://bitbucket.org/calanceus/api-test/commits/947362ec4e9ab99f63ca09f799f91f237557e35f"
#                               },
#                               "self": {
#                                    "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/947362ec4e9ab99f63ca09f799f91f237557e35f"
#                               }
#                          },
#                          "type": "commit"
#                     }
#                ],
#                "rendered": {
#                     "message": {
#                          "html": "<p>Commit #2!</p>",
#                          "markup": "markdown",
#                          "raw": "Commit #2!\n",
#                          "type": "rendered"
#                     }
#                },
#                "repository": {
#                     "full_name": "calanceus/api-test",
#                     "links": {
#                          "avatar": {
#                               "href": "https://bytebucket.org/ravatar/%7B38b213d6-3967-4cf8-a92d-8b145c54588a%7D?ts=default"
#                          },
#                          "html": {
#                               "href": "https://bitbucket.org/calanceus/api-test"
#                          },
#                          "self": {
#                               "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test"
#                          }
#                     },
#                     "name": "API Test",
#                     "type": "repository",
#                     "uuid": "{38b213d6-3967-4cf8-a92d-8b145c54588a}"
#                },
#                "summary": {
#                     "html": "<p>Commit #2!</p>",
#                     "markup": "markdown",
#                     "raw": "Commit #2!\n",
#                     "type": "rendered"
#                },
#                "type": "commit"
#           },
#           {
#                "author": {
#                     "raw": "mhammons <mxhammons@calance.com>",
#                     "type": "author"
#                },
#                "date": "2016-04-15T18:55:20+00:00",
#                "hash": "947362ec4e9ab99f63ca09f799f91f237557e35f",
#                "links": {
#                     "approve": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/947362ec4e9ab99f63ca09f799f91f237557e35f/approve"
#                     },
#                     "comments": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/947362ec4e9ab99f63ca09f799f91f237557e35f/comments"
#                     },
#                     "diff": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/diff/947362ec4e9ab99f63ca09f799f91f237557e35f"
#                     },
#                     "html": {
#                          "href": "https://bitbucket.org/calanceus/api-test/commits/947362ec4e9ab99f63ca09f799f91f237557e35f"
#                     },
#                     "patch": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/patch/947362ec4e9ab99f63ca09f799f91f237557e35f"
#                     },
#                     "self": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/947362ec4e9ab99f63ca09f799f91f237557e35f"
#                     },
#                     "statuses": {
#                          "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test/commit/947362ec4e9ab99f63ca09f799f91f237557e35f/statuses"
#                     }
#                },
#                "message": "Added a file!\n",
#                "parents": [],
#                "rendered": {
#                     "message": {
#                          "html": "<p>Added a file!</p>",
#                          "markup": "markdown",
#                          "raw": "Added a file!\n",
#                          "type": "rendered"
#                     }
#                },
#                "repository": {
#                     "full_name": "calanceus/api-test",
#                     "links": {
#                          "avatar": {
#                               "href": "https://bytebucket.org/ravatar/%7B38b213d6-3967-4cf8-a92d-8b145c54588a%7D?ts=default"
#                          },
#                          "html": {
#                               "href": "https://bitbucket.org/calanceus/api-test"
#                          },
#                          "self": {
#                               "href": "https://api.bitbucket.org/2.0/repositories/calanceus/api-test"
#                          }
#                     },
#                     "name": "API Test",
#                     "type": "repository",
#                     "uuid": "{38b213d6-3967-4cf8-a92d-8b145c54588a}"
#                },
#                "summary": {
#                     "html": "<p>Added a file!</p>",
#                     "markup": "markdown",
#                     "raw": "Added a file!\n",
#                     "type": "rendered"
#                },
#                "type": "commit"
#           }
#      ]
# }

# %%
# Create and Open File
file = open("Commit_Comments_LoopVersion", "w+")
# Create Loop to Pull Messages and Print to Text File
for value in reversed(json1["values"]):
    file.write(value["message"])
# Close File
file.close()
